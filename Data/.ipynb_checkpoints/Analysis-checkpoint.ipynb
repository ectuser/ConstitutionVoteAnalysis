# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
data = pd.read_csv('res2.csv')
data
# Out:
#            territory  ec_number  participants_number  given_bulletins_number  \
# 0    Александровская        370                  156                      98
# 1    Александровская        371                  288                     175
# 2    Александровская        372                  245                     130
# 3    Александровская        373                  887                     339
# 4    Александровская        374                 1020                     500
# ..               ...        ...                  ...                     ...
# 767        Шегарская        768                  959                     340
# 768        Шегарская        769                  632                     340
# 769        Шегарская        770                  737                     354
# 770        Шегарская        771                  573                     246
# 771        Шегарская        772                  570                     253
#
#      returned_bulletins_number  invalid_bulletins_number    turnout  \
# 0                           98                         0  62.820513
# 1                          175                         0  60.763889
# 2                          130                         0  53.061224
# 3                          339                         8  38.218715
# 4                          500                         5  49.019608
# ..                         ...                       ...        ...
# 767                        340                         1  35.453597
# 768                        340                         8  53.797468
# 769                        354                         5  48.032564
# 770                        246                         3  42.931937
# 771                        253                         2  44.385965
#
#      yes_votes_total  yes_votes_percentage  no_votes_total  \
# 0                 84                 85.71              14
# 1                150                 85.71              25
# 2                105                 80.77              25
# 3                201                 59.29             130
# 4                283                 56.60             212
# ..               ...                   ...             ...
# 767              226                 66.47             113
# 768              230                 67.65             102
# 769              240                 67.80             109
# 770              167                 67.89              76
# 771              190                 75.10              61
#
#      no_votes_percentage
# 0                  14.29
# 1                  14.29
# 2                  19.23
# 3                  38.35
# 4                  42.40
# ..                   ...
# 767                33.24
# 768                30.00
# 769                30.79
# 770                30.89
# 771                24.11
#
# [772 rows x 11 columns]

# %%
data['yes_votes_percentage'] = data['yes_votes_percentage'].astype(float)
data['yes_votes_percentage'] = data['yes_votes_percentage'].div(100)
data['no_votes_percentage'] = data['no_votes_percentage'].astype(float)
data['no_votes_percentage'] = data['no_votes_percentage'].div(100)
data['turnout'] = data['turnout'].astype(float)
data['turnout'] = data['turnout'].div(100)
data[['yes_votes_percentage', 'turnout']]
# data.loc[:, 'yes_votes_percentage':'turnout']
# Out:
#      yes_votes_percentage   turnout
# 0                  0.8571  0.628205
# 1                  0.8571  0.607639
# 2                  0.8077  0.530612
# 3                  0.5929  0.382187
# 4                  0.5660  0.490196
# ..                    ...       ...
# 767                0.6647  0.354536
# 768                0.6765  0.537975
# 769                0.6780  0.480326
# 770                0.6789  0.429319
# 771                0.7510  0.443860
#
# [772 rows x 2 columns]

# %%
# new_data = data.loc[data['territory'] == 'Томск, Ленинская']
# new_data = data.loc[data['territory'] == 'Томск, Кировская']
# new_data = data.loc[data['territory'] == 'Томск, Советская']
new_data = data.loc[data['territory'] == 'Томск, Октябрьская']
# new_data = data
figure(num=None, figsize=(10, 7), dpi=200, facecolor='w', edgecolor='k')
plt.scatter(new_data['turnout'], new_data['no_votes_percentage'], s=1, label="Против")
plt.scatter(new_data['turnout'], new_data['yes_votes_percentage'], s=1, label="За")
plt.xlabel('Явка')
plt.ylabel('Процент проголосовавших')
plt.legend(loc='upper left')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.show()

# %%
data.sort_values(by=['no_votes_percentage'], ascending=False)
# Out:
#             territory  ec_number  participants_number  given_bulletins_number  \
# 478  Томск, Кировская         94                  256                     218
# 428  Томск, Кировская         44                  282                     235
# 716           Томская        717                 2198                     985
# 135      Каргасокская        461                  532                     353
# 303      Парабельская        573                  375                     187
# ..                ...        ...                  ...                     ...
# 155      Каргасокская        481                  104                      47
# 412     Тегульдетская        625                   43                      27
# 411     Тегульдетская        624                   36                      30
# 258     Кривошеинская        527                   68                      46
# 97      Верхнекетская        423                   89                      30
#
#      returned_bulletins_number  invalid_bulletins_number   turnout  \
# 478                        218                         0  0.851562
# 428                        235                         3  0.833333
# 716                        985                         8  0.448135
# 135                        353                         3  0.663534
# 303                        187                         3  0.498667
# ..                         ...                       ...       ...
# 155                         47                         0  0.451923
# 412                         27                         0  0.627907
# 411                         30                         0  0.833333
# 258                         46                         2  0.676471
# 97                          30                         0  0.337079
#
#      yes_votes_total  yes_votes_percentage  no_votes_total  \
# 478               65                0.2982             153
# 428               95                0.4043             137
# 716              410                0.4162             567
# 135              160                0.4533             190
# 303               84                0.4492             100
# ..               ...                   ...             ...
# 155               45                0.9574               2
# 412               26                0.9630               1
# 411               29                0.9667               1
# 258               43                0.9348               1
# 97                30                1.0000               0
#
#      no_votes_percentage
# 478               0.7018
# 428               0.5830
# 716               0.5756
# 135               0.5382
# 303               0.5348
# ..                   ...
# 155               0.0426
# 412               0.0370
# 411               0.0333
# 258               0.0217
# 97                0.0000
#
# [772 rows x 11 columns]

# %%
new_data = data
figure(num=None, figsize=(10, 7), dpi=200, facecolor='w', edgecolor='k')
for i in data['territory'].unique():
    new_data = data.loc[data['territory'] == i]
    plt.scatter(new_data['turnout'], new_data['yes_votes_percentage'], s=1, label=i)
plt.xlabel('Явка')
plt.ylabel('Процент проголосовавших за')
plt.legend(loc='upper left')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.show()

# %%
data.loc[data['no_votes_percentage'] > 0.45]
# Out:
#               territory  ec_number  participants_number  \
# 6       Александровская        376                  959
# 135        Каргасокская        461                  532
# 138        Каргасокская        464                 1225
# 158        Каргасокская        484                 2399
# 160        Каргасокская        486                  436
# 303        Парабельская        573                  375
# 310        Парабельская        580                 1498
# 425    Томск, Кировская         41                  284
# 428    Томск, Кировская         44                  282
# 437    Томск, Кировская         53                 1327
# 443    Томск, Кировская         59                 1043
# 478    Томск, Кировская         94                  256
# 480    Томск, Кировская         96                 1359
# 481    Томск, Кировская        212                 1723
# 498    Томск, Ленинская        184                 1094
# 515    Томск, Ленинская        201                 1715
# 525    Томск, Ленинская        570                 1722
# 528  Томск, Октябрьская         99                 2333
# 580  Томск, Октябрьская        151                 2177
# 597    Томск, Советская          2                 2373
# 612    Томск, Советская         17                 2388
# 614    Томск, Советская         19                 1510
# 618    Томск, Советская         23                  329
# 640             Томская        641                 1521
# 657             Томская        658                 2195
# 716             Томская        717                 2198
#
#      given_bulletins_number  returned_bulletins_number  \
# 6                       446                        446
# 135                     353                        353
# 138                     600                        600
# 158                    1282                       1282
# 160                     303                        303
# 303                     187                        187
# 310                    1073                       1073
# 425                     137                        137
# 428                     235                        235
# 437                     494                        494
# 443                     585                        585
# 478                     218                        218
# 480                     732                        732
# 481                     668                        668
# 498                     432                        432
# 515                     745                        745
# 525                     700                        700
# 528                     825                        825
# 580                     852                        852
# 597                    1088                       1088
# 612                     972                        970
# 614                     629                        629
# 618                     240                        240
# 640                     650                        650
# 657                     793                        793
# 716                     985                        985
#
#      invalid_bulletins_number   turnout  yes_votes_total  \
# 6                           9  0.465068              231
# 135                         3  0.663534              160
# 138                         4  0.489796              317
# 158                        19  0.534389              619
# 160                         5  0.694954              141
# 303                         3  0.498667               84
# 310                         9  0.716288              509
# 425                         0  0.482394               70
# 428                         3  0.833333               95
# 437                         3  0.372268              262
# 443                         6  0.560882              304
# 478                         0  0.851562               65
# 480                        12  0.538631              389
# 481                         4  0.387696              343
# 498                         4  0.394881              232
# 515                         2  0.434402              375
# 525                         5  0.406504              366
# 528                         7  0.353622              416
# 580                         0  0.391364              445
# 597                         6  0.458491              578
# 612                         8  0.407035              515
# 614                         1  0.416556              324
# 618                         1  0.729483              126
# 640                         4  0.427350              347
# 657                         5  0.361276              403
# 716                         8  0.448135              410
#
#      yes_votes_percentage  no_votes_total  no_votes_percentage
# 6                  0.5179             206               0.4619
# 135                0.4533             190               0.5382
# 138                0.5283             279               0.4650
# 158                0.4828             644               0.5023
# 160                0.4653             157               0.5182
# 303                0.4492             100               0.5348
# 310                0.4744             555               0.5172
# 425                0.5109              67               0.4891
# 428                0.4043             137               0.5830
# 437                0.5304             229               0.4636
# 443                0.5197             275               0.4701
# 478                0.2982             153               0.7018
# 480                0.5314             331               0.4522
# 481                0.5135             321               0.4805
# 498                0.5370             196               0.4537
# 515                0.5034             368               0.4940
# 525                0.5229             329               0.4700
# 528                0.5042             402               0.4873
# 580                0.5223             407               0.4777
# 597                0.5313             504               0.4632
# 612                0.5309             447               0.4608
# 614                0.5151             304               0.4833
# 618                0.5250             113               0.4708
# 640                0.5338             299               0.4600
# 657                0.5082             385               0.4855
# 716                0.4162             567               0.5756
