# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
data = pd.read_csv('res1.csv')
data
# Out:
#            territory  ec_number  participants_number  given_bulletins_number  \
# 0    Александровская        370                  156                      98
# 1    Александровская        371                  288                     175
# 2    Александровская        372                  245                     130
# 3    Александровская        373                  887                     339
# 4    Александровская        374                 1020                     500
# ..               ...        ...                  ...                     ...
# 697        Шегарская        768                  959                     340
# 698        Шегарская        769                  632                     340
# 699        Шегарская        770                  737                     354
# 700        Шегарская        771                  573                     246
# 701        Шегарская        772                  570                     253
#
#      returned_bulletins_number  invalid_bulletins_number    turnout  \
# 0                           98                         0  62.820513
# 1                          175                         0  60.763889
# 2                          130                         0  53.061224
# 3                          339                         8  38.218715
# 4                          500                         5  49.019608
# ..                         ...                       ...        ...
# 697                        340                         1  35.453597
# 698                        340                         8  53.797468
# 699                        354                         5  48.032564
# 700                        246                         3  42.931937
# 701                        253                         2  44.385965
#
#      yes_votes_total  yes_votes_percentage  no_votes_total  \
# 0                 84                 85.71              14
# 1                150                 85.71              25
# 2                105                 80.77              25
# 3                201                 59.29             130
# 4                283                 56.60             212
# ..               ...                   ...             ...
# 697              226                 66.47             113
# 698              230                 67.65             102
# 699              240                 67.80             109
# 700              167                 67.89              76
# 701              190                 75.10              61
#
#      no_votes_percentage
# 0                  14.29
# 1                  14.29
# 2                  19.23
# 3                  38.35
# 4                  42.40
# ..                   ...
# 697                33.24
# 698                30.00
# 699                30.79
# 700                30.89
# 701                24.11
#
# [702 rows x 11 columns]

# %%
data['yes_votes_percentage'] = data['yes_votes_percentage'].astype(float)
data['yes_votes_percentage'] = data['yes_votes_percentage'].div(100)
data['no_votes_percentage'] = data['no_votes_percentage'].astype(float)
data['no_votes_percentage'] = data['no_votes_percentage'].div(100)
data['turnout'] = data['turnout'].astype(float)
data['turnout'] = data['turnout'].div(100)
data[['yes_votes_percentage', 'turnout']]
# data.loc[:, 'yes_votes_percentage':'turnout']
# Out:
#      yes_votes_percentage   turnout
# 0                  0.8571  0.628205
# 1                  0.8571  0.607639
# 2                  0.8077  0.530612
# 3                  0.5929  0.382187
# 4                  0.5660  0.490196
# ..                    ...       ...
# 697                0.6647  0.354536
# 698                0.6765  0.537975
# 699                0.6780  0.480326
# 700                0.6789  0.429319
# 701                0.7510  0.443860
#
# [702 rows x 2 columns]

# %%
figure(num=None, figsize=(8, 5), dpi=200, facecolor='w', edgecolor='k')
plt.scatter(data['turnout'], data['yes_votes_percentage'], c='r', s=1, label="За")
plt.scatter(data['turnout'], data['no_votes_percentage'], c='b', s=1, label="Против")
plt.xlabel('Явка')
plt.ylabel('Процент проголосовавших')
plt.legend(loc='upper left')
plt.show()
